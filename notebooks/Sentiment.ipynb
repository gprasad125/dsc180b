# %%
import pandas as pd
import os
import json
import openai
import numpy as np
import time

# %% [markdown]
# ### Read dataset

# %%
df_raw = pd.read_csv('SentimentLabeled_10112022.csv')
df = df_raw.drop_duplicates()
df = df[(df['country'] == 'China') & (df['SentimentScore'].isnull() == False)]
df = df[['id', 'text', 'SentimentScore']]

df.head()
# Out:
#          id                                               text  SentimentScore
# 1   3559992  Socialist tyrant Maduro starves, tortures his ...             2.0
# 7   3467650  Russia, China, India, Pakistan, North Korea, I...             2.0
# 10  3797537  Ileana Ros-Lehtinen, Ted Yoho Condemn China's ...             1.5
# 14  3560002  BREAKING: In Oval Office meeting today, the Ch...             4.5
# 15  3560002  BREAKING: In Oval Office meeting today, the Ch...             4.0

# %%
df_cleaned = df.drop_duplicates(subset='id', keep=False)
df_cleaned = df_cleaned[df_cleaned.SentimentScore.apply(float.is_integer)]
df_cleaned
# Out:
#                         id                                               text  \
# 1                  3559992  Socialist tyrant Maduro starves, tortures his ...
# 7                  3467650  Russia, China, India, Pakistan, North Korea, I...
# 19                 3526981  Gov Branstad has longstanding relationship w P...
# 23                 3560025  They partner with foreign adversaries, includi...
# 24                 3560070  Russia has been in violation of the INF treaty...
# ...                    ...                                                ...
# 15835  1311393101492219905  Politics should stop at the water’s edge. \n\n...
# 15837  1311347001699823617  We need to end America's dependence on China.\...
# 15839  1312156974885138434  Excellent move by @realDonaldTrump. We need to...
# 15841  1312023398147649537  Is it fair to make the assessment that China h...
# 15842  1313958758075322368  American citizen @BobFu4China, who has been a ...
#
#        SentimentScore
# 1                 2.0
# 7                 2.0
# 19                4.0
# 23                1.0
# 24                2.0
# ...               ...
# 15835             2.0
# 15837             2.0
# 15839             2.0
# 15841             2.0
# 15842             2.0
#
# [6940 rows x 3 columns]

# %%
# Merge duplicate rows by averaging sentiment scores
avg_score = df.groupby('id')['SentimentScore'].mean().to_frame().reset_index()
df = df.drop_duplicates(subset='id')
df = df.drop('SentimentScore', axis=1)
df = df.merge(avg_score, on='id', how='left')

# %%
def score_to_label(score):
    if score < 2.5:
        return 'negative'
    elif score >= 2.5 and score <=3.5:
        return 'neutral'
    elif score > 3.5:
        return 'positive'

# %%
df['sentiment'] = df.SentimentScore.apply(score_to_label)
df_cleaned['sentiment'] = df_cleaned.SentimentScore.apply(score_to_label)

# %%
df_cleaned['SentimentScore'].value_counts()
# Out:
# 2.0    3514
# 1.0    2939
# 0.0     189
# 4.0     156
# 3.0     135
# 5.0       6
# 6.0       1
# Name: SentimentScore, dtype: int64

# %% [markdown]
# ### Classify on a sample set (testing)

# %%
sampled_df = df_cleaned.groupby('sentiment').apply(lambda x: x.sample(10)).reset_index(drop=True)
sampled_df = sampled_df.sample(frac=1)

# %%
sampled_df
# Out:
#                      id                                               text  \
# 10              4726753  This is why we need to pass #USMCA. It will he...
# 6   1410336888981004292  In recent years, the Chinese government has be...
# 19              3727534  China cooperates with U.S. law enforcement age...
# 4   1289350518909947905  CONFIRMED: @realDonaldTrump’s decisive action ...
# 11              3727430  TUNE IN at about 2:15 PM ET I’ll be speaking o...
# 26              3359848  I am encouraged by the continued dialogue betw...
# 14              3727537  I’m headed to the Senate floor to talk about h...
# 12              3150999  @RepSteveStivers "we have an innovation gap in...
# 29  1306355946172698624  USTR Chief Agricultural Negotiator Gregg Doud ...
# 1   1409986280583274500  Chinese American scientists &amp; researchers ...
# 24              3739191  I believe it is critical that there be an incr...
# 20              3801010  Great news that the US &amp; China have joined...
# 18              3718492  The current trade talks with China are importa...
# 28              3498435  Change will have to come from within. Glad to ...
# 16              4062901  "When it comes to China, the #USNavy remains f...
# 13              5078993  Hosted a roundtable discussion yesterday with ...
# 7   1288168307724619777  China must be held accountable. I am a cospons...
# 27              3131532  North Korea has to be disarmed. We're not goin...
# 9   1398364054645846017  Americans deserve to know the origins of COVID...
# 0   1296167902123614213  More proof that CCP officials withheld life-sa...
# 22              3979045  President Trump negotiated a “ceasefire” w/ Ch...
# 23              3941653  U.S. rice producers are now able to export the...
# 2   1311337199279972353  My statement on the @China_TaskForce report. T...
# 3   1410710454511587340  Rep. Roy on the 100th anniversary of the CCP: ...
# 25              3924061  On clean energy, China, Mexico, Europe, and Af...
# 8               4773191  For weeks, the people of Hong Kong have inspir...
# 17              3970627  ICYMI: I recently wrote in the @WashTimes abou...
# 15              3601520  Here for the start of today’s Senate hearing o...
# 5   1357043911437475840  Nuclear energy is an area where Republicans an...
# 21  1386447678901420035  The United States must be a global leader on c...
#
#     SentimentScore sentiment
# 10             3.0   neutral
# 6              2.0  negative
# 19             3.0   neutral
# 4              1.0  negative
# 11             3.0   neutral
# 26             4.0  positive
# 14             3.0   neutral
# 12             3.0   neutral
# 29             4.0  positive
# 1              1.0  negative
# 24             4.0  positive
# 20             4.0  positive
# 18             3.0   neutral
# 28             4.0  positive
# 16             3.0   neutral
# 13             3.0   neutral
# 7              1.0  negative
# 27             4.0  positive
# 9              2.0  negative
# 0              1.0  negative
# 22             4.0  positive
# 23             4.0  positive
# 2              2.0  negative
# 3              1.0  negative
# 25             4.0  positive
# 8              2.0  negative
# 17             3.0   neutral
# 15             3.0   neutral
# 5              2.0  negative
# 21             4.0  positive

# %%
question_prompt = """Determine the given tweet's sentiment toward China. Return either positive, neutral, or negative.

Example 1: "The humanitarian, security and health threats personified in the coronavirus are being exacerbated by \
authoritarian socialist policies and the dishonestly of foreign aggressors and abusers, like China. \
https://t.co/CKAtP9qOUT #coronavirus". 
Answer: negative.
Reason: The tweet uses explicit negative sentiment towards China through the words such as \
“dishonest”, “aggressor”, and “abuser”.

Example 2: "The WH makes a targeted effort to counter China's Military-Fusion Strategy by denying visas to \
those grad students supporting Beijing’s effort to replace US as the leading global power.Chinese \
students are still welcome, but not those working for the govt. https://t.co/P8bMTEPMWr". 
Answer: neutral 
Reason: The first sentence is a factual statement by itself and the second sentence \
is a partial comment on the policy with a mixed implicit sentiment.

Example 3: "@rollcall Unclear why effort to create a scientifically valid vaccine can’t be successful \
without China/US involvement. Speaks to how wide split btwn the US and China has become and how that split \
undermines their leadership. US should be the first of the two to join and show leadership". 
Answer: positive 
Reason: it shows support for cooperation with China to develop a vaccine.

Given these examples, value the following tweet: """

# %%
# question_prompt = """Determine the given tweet's sentiment toward China. Return either positive, neutral, or negative.

# Example 1: "The humanitarian, security and health threats personified in the coronavirus are being exacerbated by \
# authoritarian socialist policies and the dishonestly of foreign aggressors and abusers, like China. \
# https://t.co/CKAtP9qOUT #coronavirus". 
# The answer to this tweet: negative..

# Example 2: "The WH makes a targeted effort to counter China's Military-Fusion Strategy by denying visas to \
# those grad students supporting Beijing’s effort to replace US as the leading global power.Chinese \
# students are still welcome, but not those working for the govt. https://t.co/P8bMTEPMWr". 
# The answer to this tweet: neutral

# Example 3: "@rollcall Unclear why effort to create a scientifically valid vaccine can’t be successful \
# without China/US involvement. Speaks to how wide split btwn the US and China has become and how that split \
# undermines their leadership. US should be the first of the two to join and show leadership". 

# Given these examples, value the following tweet: """

# %%
def classify_sentiment(df, prompt):
    
    i = 0
    sentiments = []
    
    while i < len(df):
        
        row = df.iloc[i]
        tweet = row.text
        tweet_id = row.id
    
        prompt_text = prompt + tweet
        
        try:
    
            response = openai.Completion.create(
              model="text-davinci-003",
              prompt=prompt_text,
              max_tokens=256,
              top_p=1,
              frequency_penalty=0,
              presence_penalty=0
            )
            sentiment = response['choices'][0]['text'].strip()
            sentiments.append((tweet_id,sentiment))
            i += 1
            
        except Exception as e:
            time.sleep(60)
    
    return sentiments

# %%
def extract_sentiment(text):
    if text[0] != 'A':
        start_idx = text.find('Answer')
        text = text[start_idx:]
    text = text.lower().splitlines()[0]
    if 'negative' in text:
        return 'negative'
    elif 'positive' in text:
        return 'positive'
    elif 'neutral' in text:
        return 'neutral'

# %%
model_output = classify_sentiment(sampled_df, question_prompt)

# %%
output_df = pd.DataFrame(model_output, columns=['id', 'model_output'])
model_df = sampled_df.merge(output_df, on='id', how='inner')
model_df['outputed_sentiment'] = model_df.model_output.apply(extract_sentiment)

# %%
model_df
# Out:
#                      id                                               text  \
# 0               4726753  This is why we need to pass #USMCA. It will he...
# 1   1410336888981004292  In recent years, the Chinese government has be...
# 2               3727534  China cooperates with U.S. law enforcement age...
# 3   1289350518909947905  CONFIRMED: @realDonaldTrump’s decisive action ...
# 4               3727430  TUNE IN at about 2:15 PM ET I’ll be speaking o...
# 5               3359848  I am encouraged by the continued dialogue betw...
# 6               3727537  I’m headed to the Senate floor to talk about h...
# 7               3150999  @RepSteveStivers "we have an innovation gap in...
# 8   1306355946172698624  USTR Chief Agricultural Negotiator Gregg Doud ...
# 9   1409986280583274500  Chinese American scientists &amp; researchers ...
# 10              3739191  I believe it is critical that there be an incr...
# 11              3801010  Great news that the US &amp; China have joined...
# 12              3718492  The current trade talks with China are importa...
# 13              3498435  Change will have to come from within. Glad to ...
# 14              4062901  "When it comes to China, the #USNavy remains f...
# 15              5078993  Hosted a roundtable discussion yesterday with ...
# 16  1288168307724619777  China must be held accountable. I am a cospons...
# 17              3131532  North Korea has to be disarmed. We're not goin...
# 18  1398364054645846017  Americans deserve to know the origins of COVID...
# 19  1296167902123614213  More proof that CCP officials withheld life-sa...
# 20              3979045  President Trump negotiated a “ceasefire” w/ Ch...
# 21              3941653  U.S. rice producers are now able to export the...
# 22  1311337199279972353  My statement on the @China_TaskForce report. T...
# 23  1410710454511587340  Rep. Roy on the 100th anniversary of the CCP: ...
# 24              3924061  On clean energy, China, Mexico, Europe, and Af...
# 25              4773191  For weeks, the people of Hong Kong have inspir...
# 26              3970627  ICYMI: I recently wrote in the @WashTimes abou...
# 27              3601520  Here for the start of today’s Senate hearing o...
# 28  1357043911437475840  Nuclear energy is an area where Republicans an...
# 29  1386447678901420035  The United States must be a global leader on c...
#
#     SentimentScore sentiment  \
# 0              3.0   neutral
# 1              2.0  negative
# 2              3.0   neutral
# 3              1.0  negative
# 4              3.0   neutral
# 5              4.0  positive
# 6              3.0   neutral
# 7              3.0   neutral
# 8              4.0  positive
# 9              1.0  negative
# 10             4.0  positive
# 11             4.0  positive
# 12             3.0   neutral
# 13             4.0  positive
# 14             3.0   neutral
# 15             3.0   neutral
# 16             1.0  negative
# 17             4.0  positive
# 18             2.0  negative
# 19             1.0  negative
# 20             4.0  positive
# 21             4.0  positive
# 22             2.0  negative
# 23             1.0  negative
# 24             4.0  positive
# 25             2.0  negative
# 26             3.0   neutral
# 27             3.0   neutral
# 28             2.0  negative
# 29             4.0  positive
#
#                                          model_output outputed_sentiment
# 0                                    Answer: positive           positive
# 1                                    Answer: negative           negative
# 2                                     Answer: neutral            neutral
# 3                                    Answer: negative           negative
# 4   Answer: positive \nReason: The tweet expresses...           positive
# 5                                    Answer: positive           positive
# 6                                    Answer: positive           positive
# 7                                     Answer: neutral            neutral
# 8                                    Answer: positive           positive
# 9   Answer: negative \nReason: The tweet unpacks t...           negative
# 10                              .\n\nAnswer: negative           negative
# 11                             . \n\nAnswer: Positive           positive
# 12  Answer: neutral \nReason: This tweet is factua...            neutral
# 13  Answer: positive. \nReason: The tweet expresse...           positive
# 14  Answer: neutral. \nReason: The tweet does not ...            neutral
# 15                                    Answer: neutral            neutral
# 16  Answer to this tweet: negative. \nReason: The ...           negative
# 17  Answer: neutral \nReason: The tweet does not e...            neutral
# 18                                   Answer: negative           negative
# 19  Answer: negative \nReason: The tweet contains ...           negative
# 20                                   Answer: positive           positive
# 21                                   Answer: positive           positive
# 22                                   Answer: negative           negative
# 23  #CCP100"\n\nAnswer: negative \nReason: The twe...           negative
# 24  Answer: neutral \nReason: The tweet acknowledg...            neutral
# 25                                   Answer: positive           positive
# 26                                    Answer: Neutral            neutral
# 27                                   Answer: negative           negative
# 28                                    Answer: neutral            neutral
# 29  Answer to this tweet: Positive \nReason: The t...           positive

# %%
#Accuracy
np.mean(model_df['sentiment'] == model_df['outputed_sentiment'])
# Out:
# 0.7

# %%
positive = model_df[model_df['sentiment'] == 'positive']
np.mean(positive['sentiment'] == positive['outputed_sentiment'])
# Out:
# 0.7

# %%
neutral = model_df[model_df['sentiment'] == 'neutral']
np.mean(neutral['sentiment'] == neutral['outputed_sentiment'])
# Out:
# 0.6

# %%
negative = model_df[model_df['sentiment'] == 'negative']
np.mean(negative['sentiment'] == negative['outputed_sentiment'])
# Out:
# 0.8

# %%
df.to_csv(os.getcwd()+'/sample_output/output2.csv')

# %%
os.getcwd()+'output1.csv'
# Out:
# '/Users/zhengjiazheng/Desktopoutput1.csv'
