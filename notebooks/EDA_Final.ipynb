# %% [markdown]
# ## Exploratory Data Analysis
#
# In this file, we'll set up and explore our data. Our visualizations will inform the results of our past work, as well as give an idea of what to expect from the modeling.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sys

import warnings
warnings.filterwarnings('ignore')

# add source code path
sys.path.append('../src/notebooks')
from nb_functions import *

# %% [markdown]
# One of the most significant detractors for our Quarter 1 reports was the significant imbalance of classes in our data. We'll visualize those imbalances for you via some generated plots of data distribution.

# %%
path = '../data/raw/SentimentLabeled_10112022.csv'
df = load_full_data(path)
df_relevance = load_df_relevance(df)
df_sentiment = load_df_sentiment(df)

# %% [markdown]
# #### Political Parties
#
# As the plot below shows, our dataset contains far more Republican Tweets than Democratic ones, over twice the amount. As we will later see, this plays into the high level of negative-sentiment Tweets in the dataset.

# %%
plot, axis = visualize('party', df)
plot.show()

# %% [markdown]
# #### States
#
# We see that the most represented U.S. states are ones that have the highest population -- Texas, Florida, California, New York, etc.
#
# This distribution also helps explain the high amount of Republican accounts; specifically, the high representation of Republican states like Texas, Florida, and Tennessee.

# %%
plot, axis = visualize('state', df)
plot.show()

# %% [markdown]
# #### Relevance
#
# As we can see here, we have over 2x the amount of relevant Tweets as irrelevant Tweets in our dataset.

# %%
plot, axis = visualize('relevance', df_relevance)
plot.show()

# %%
plot, axis = visualize('sentiment', df_sentiment)
plot.show()

# %%
plot, axis = visualize('overtime', df)
plot.show()
